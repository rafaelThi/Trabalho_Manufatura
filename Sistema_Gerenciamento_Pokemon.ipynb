# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelThi/Trabalho_Manufatura/blob/master/Sistema_Gerenciamento_Pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criação de um sistema de gerenciamento de cards Pokemon utilizando um banco de dados feito no SQLite Online, chamado "pokemon.db". Nesse sistema de Gerenciamento, o usuário pode:
#
#
# *   Pesquisar todos os cards de Pokemon cadastrados
# *   Cadastrar mais Pokemons
# *   Buscar por Nome
# *   Buscar por Id
# *   Buscar por Serie
# *   Buscar por Coleção
# *   Buscar por Raridade
# *   Buscar por Quantidade
# *   Fazer Update dos Dados do Banco
# *   Apagar um Card do Banco

# %% [markdown]
# Define a classe pokemon e todos os atribulos necessários para criação de um novo cadastro de card Pokemon no Banco de Dados.

# %%
class Pokemon():
  #Construtor
  def __init__(self, id, nome, imagem,  serie, colecao, raridade,quantidade):
    self.id = id
    self.nome = nome
    self.imagem = imagem
    self.serie = serie
    self.colecao = colecao
    self.raridade = raridade
    self.quantidade = quantidade

# %% [markdown]
# Funções para requisição e alteração de dados do Banco.

# %%
class PokemonDAO():
  def buscarTodosOsPokemons():
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    cursor.execute('''SELECT * FROM Pokemon''')
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons

  def cadastrarPokemon(pokemon):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    cursor.execute('''INSERT INTO Pokemon VALUES (?,?,?,?,?,?,?);''',(pokemon.id, pokemon.nome, \
                                                                    pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))
    conn.commit()
    conn.close()

  def buscarPorNome(nome):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    print(nome)
    cursor.execute(''' SELECT * FROM Pokemon WHERE nome like "{}";'''.format(nome))
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons

  def buscarPorID(id):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    print(id)
    cursor.execute(''' SELECT * FROM Pokemon WHERE id like "{}";'''.format(id))
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons
  
  def buscarPorRaridade(raridade):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    print(raridade)
    cursor.execute(''' SELECT * FROM Pokemon WHERE raridade like "{}";'''.format(raridade))
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons
    
  def buscarPorSerie(serie):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    print(serie)
    cursor.execute(''' SELECT * FROM Pokemon WHERE serie like "{}";'''.format(serie))
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons

  def buscarPorColecao(colecao):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    print(colecao)
    cursor.execute(''' SELECT * FROM Pokemon WHERE colecao like "{}";'''.format(colecao))
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons


  def buscarPorQuantidade(quantidade):
    conn = sqlite3.connect('pokemon.db')
    cursor = conn.cursor()
    print(quantidade)
    cursor.execute(''' SELECT * FROM Pokemon WHERE quantidade like "{}";'''.format(quantidade))
    pokemons = []

    for linha in cursor.fetchall():
      pokemons.append(Pokemon(linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6]))
    conn.close()

    return pokemons

  def UpdatePokemon(atr, id):
    conn = sqlite3.connect("pokemon.db")
    cursor = conn.cursor()
    print(id)
    print(atr)
    cursor.execute(''' UPDATE Pokemon SET {} WHERE id like "{}";'''.format(atr, id))
    conn.commit()   

  def DeletarPokemon(id):
    conn = sqlite3.connect("pokemon.db")
    cursor = conn.cursor()
    print(id)
    cursor.execute(''' DELETE FROM Pokemon WHERE id = "{}";'''.format(id))
    conn.commit()

# %% [markdown]
# Interface de usuário, onde pode escolher qual o comando quer atualizar ou visualizar sua tabela.

# %%
import sqlite3

def menu():
  print('1 - Mostrar todos os Pokemons')
  print('2 - Cadastrar outro Pokemon')
  print('3 - Busca por Nome')
  print('4 - Buscar por Id')
  print('5 - Buscar por Raridade')
  print('6 - Buscar por Serie')
  print('7 - Buscar por Colecao')
  print('8 - Buscar por quantidade')
  print('9 - Updade Pokemon')
  print('10 - Deletar Pokemon')

def mostrarListaDePokemons():
  print('Lista de Pokemons:')
  print('ID\tNome\tImagem\tSerie\tColecao\tRaridade\tQuantidade')
  for pokemon in PokemonDAO.buscarTodosOsPokemons():
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))

def cadastrarPokemon():
  id = input('Id do Pokemon:')
  nome = input('Nome do Pokemon:')
  imagem = input('Imagem:')
  serie = input('Serie:')
  colecao = input('Colecao:')
  raridade = input('Raridade:')
  quantidade = int(input('Quantidade:'))
  PokemonDAO.cadastrarPokemon(Pokemon(id, nome, imagem, serie, colecao, raridade, quantidade))

def buscarPorID():
  id = input("Id do Pokemon:")
  for pokemon in PokemonDAO.buscarPorID(id):
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))

def buscarPorNomePokemon():
  nome = input("Nome do Pokemon:")
  for pokemon in PokemonDAO.buscarPorNome(nome):
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))

def buscarPorSeriePokemon():
  serie = input("Serie:")
  for pokemon in PokemonDAO.buscarPorSerie(serie):
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))
    
def buscarPorColecaoPokemon():
  colecao = input("Colecao:")
  for pokemon in PokemonDAO.buscarPorColecao(colecao):
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))

def buscarPorRaridadePokemon():
  raridade = input("Raridade:")
  for pokemon in PokemonDAO.buscarPorRaridade(raridade):
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))
def buscarPorQtdPokemon():
  quantidade = int(input("Quantidade:"))
  for pokemon in PokemonDAO.buscarPorQuantidade(quantidade):
    print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(pokemon.id, pokemon.nome,pokemon.imagem, pokemon.serie, pokemon.colecao,\
                                                                   pokemon.raridade, pokemon.quantidade))
    
def Update():
  atr = input("Atributo = "": ")
  id = input("Id do Pokemon:")
  PokemonDAO.UpdatePokemon(atr, id)

def Delete():
  id = input("Id do Pokemon: ")
  x = input("Deseja mesmo deletar? s/n")
  if x == "s":
    PokemonDAO.DeletarPokemon(id)

continuar = True

while continuar:
  print("Sistema de Gerenciamento de Pokemons")
  menu()
  opcao = int(input("Opcao desejada:"))
  if opcao == 1:
    mostrarListaDePokemons()
  elif opcao == 2:
    cadastrarPokemon()
  elif opcao == 3:
    buscarPorNomePokemon()
  elif opcao == 4:
    buscarPorID()
  elif opcao == 5:
    buscarPorRaridadePokemon()
  elif opcao == 6:
    buscarPorSeriePokemon()
  elif opcao == 7:
    buscarPorColecaoPokemon()
  elif opcao == 8:
    buscarPorQtdPokemon()
  elif opcao == 9:
    Update()
  elif opcao == 10:
    Delete()
  continuar = input("Deseja continuar? s/n")
  if continuar == 'n':
    break
# Out:
# Sistema de Gerenciamento de Pokemons
# 1 - Mostrar todos os Pokemons
# 2 - Cadastrar outro Pokemon
# 3 - Busca por Nome
# 4 - Buscar por Id
# 5 - Buscar por Raridade
# 6 - Buscar por Serie
# 7 - Buscar por Colecao
# 8 - Buscar por quantidade
# 9 - Updade Pokemon
# 10 - Deletar Pokemon
# Opcao desejada:1
# Lista de Pokemons:
# ID	Nome	Imagem	Serie	Colecao	Raridade	Quantidade
# sm1-22	oi	https://images.pokemontcg.io/sm1/22_hires.png	Sun & Moon	Sun & Moon	Rare Holo	2
# sm1-31	Poliwhirl	https://images.pokemontcg.io/sm1/31_hires.png	Sun & Moon	Sun & Moon	Uncommon	3
# sm1-32	Poliwrath	https://images.pokemontcg.io/sm1/32_hires.png	Sun & Moon	Sun & Moon	Rare Holo	4
# sm1-123	Nest Ball	https://images.pokemontcg.io/sm1/123_hires.png	Sun & Moon	Sun & Moon	Uncommon	7
# Deseja continuar? s/ns
# Sistema de Gerenciamento de Pokemons
# 1 - Mostrar todos os Pokemons
# 2 - Cadastrar outro Pokemon
# 3 - Busca por Nome
# 4 - Buscar por Id
# 5 - Buscar por Raridade
# 6 - Buscar por Serie
# 7 - Buscar por Colecao
# 8 - Buscar por quantidade
# 9 - Updade Pokemon
# 10 - Deletar Pokemon
